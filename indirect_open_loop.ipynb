# %% [markdown]
# ### Indirect Open Loop Controller Analysis
#
# This notebook contains the analysis of the indirect open loop controller across temperatures.

# %%
import import_ipynb
from kinetic_parameters import rate

# %%
rate(controller="indirect_open_loop", temperature_C=30)
# Out:
# {'alpha_X': 0.15183,
#  'alpha_Y': 0.0015183,
#  'alpha_Y+': 1.5183,
#  'delta_X': 0.0075913,
#  'delta_Y': 0.0075913,
#  'kappa': 0.0,
#  'omega': 5014000.0,
#  'nu': 2.0056,
#  'beta_A': 0.00015183,
#  'delta_A': 7.5913e-05,
#  'alpha_O': 0.0015183,
#  'alpha_O+': 1.5183,
#  'delta_O': 0.0030365}
